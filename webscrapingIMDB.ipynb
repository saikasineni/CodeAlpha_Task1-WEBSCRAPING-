# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
titles = []
prices = []
ratings = []
availability = []

# %%
for page in range(1,26):

    url = f"https://books.toscrape.com/catalogue/page-{page}.html"

    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all("article", class_="product_pod")

    for book in books:

        # title
        title = book.h3.a["title"]

        # price
        price = book.find("p", class_="price_color").text

        # rating
        rating = book.p["class"][1]

        # availability
        stock = book.find("p", class_="instock availability").text.strip()

        titles.append(title)
        prices.append(price)
        ratings.append(rating)
        availability.append(stock)

# %%
data = pd.DataFrame({
    "Title": titles,
    "Price": prices,
    "Rating": ratings,
    "Availability": availability
})

data.head()
# Out:
#                                    Title    Price Rating Availability
# 0                   A Light in the Attic  Â£51.77  Three     In stock
# 1                     Tipping the Velvet  Â£53.74    One     In stock
# 2                             Soumission  Â£50.10    One     In stock
# 3                          Sharp Objects  Â£47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five     In stock

# %%
print(data.shape)
# Out:
# (500, 4)

# %%
data.to_csv("books_500_dataset.csv", index=False)

# %%
data.tail()
# Out:
#                                                  Title    Price Rating  \
# 495  Unreasonable Hope: Finding Faith in the God Wh...  Â£46.33    Two
# 496                               Under the Tuscan Sun  Â£37.33  Three
# 497         Toddlers Are A**holes: It's Not Your Fault  Â£25.55    One
# 498  The Year of Living Biblically: One Man's Humbl...  Â£34.72    One
# 499                                          The Whale  Â£35.96   Four
#
#     Availability
# 495     In stock
# 496     In stock
# 497     In stock
# 498     In stock
# 499     In stock

# %%
len(data)
# Out:
# 500
